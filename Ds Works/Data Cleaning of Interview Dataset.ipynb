# %%
import pandas as pd
md=pd.read_excel('D:/Aditya/datasets/the-interview-attendance-problem/interview.xlsx')
md.head()
# Out:
#         Date Client name         Industry Location        Position_Type  \
# 0 2015-02-13     Hospira  Pharmaceuticals  Chennai  Production- Sterile
# 1 2015-02-13     Hospira  Pharmaceuticals  Chennai  Production- Sterile
# 2 2015-02-13     Hospira  Pharmaceuticals  Chennai  Production- Sterile
# 3 2015-02-13     Hospira  Pharmaceuticals  Chennai  Production- Sterile
# 4 2015-02-13     Hospira  Pharmaceuticals  Chennai  Production- Sterile
#
#   SkillSet_Name    Interview_type Candidate_ID Gender Current_Location  \
# 0       Routine  Scheduled Walkin  Candidate 1   Male          Chennai
# 1       Routine  Scheduled Walkin  Candidate 2   Male          Chennai
# 2       Routine  Scheduled Walkin  Candidate 3   Male          Chennai
# 3       Routine  Scheduled Walkin  Candidate 4   Male          Chennai
# 4       Routine  Scheduled Walkin  Candidate 5   Male          Chennai
#
#       ...     Venue_Clear Call_Letter_Received Expected_Attendance  \
# ...

# %%
md.shape
# Out:
# (1234, 28)

# %%
md.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 28 columns):
# Date                      1178 non-null datetime64[ns]
# Client name               1234 non-null object
# Industry                  1233 non-null object
# Location                  1233 non-null object
# Position_Type             1233 non-null object
# SkillSet_Name             1233 non-null object
# Interview_type            1233 non-null object
# Candidate_ID              1233 non-null object
# Gender                    1233 non-null object
# Current_Location          1233 non-null object
# Company_Location          1233 non-null object
# Interview_Venue           1233 non-null object
# Candidate_Hometown        1233 non-null object
# Permission_Obtained       1029 non-null object
# No_Unscheduled_Meeting    986 non-null object
# Follow-Up_Call_OK         986 non-null object
# Alternate_Number_Given    986 non-null object
# CV_JD_Ready               985 non-null object
# ...

# %%
md['Expected_Attendance'].head()
# Out:
# 0          Yes
# 1          Yes
# 2    Uncertain
# 3    Uncertain
# 4    Uncertain
# Name: Expected_Attendance, dtype: object
